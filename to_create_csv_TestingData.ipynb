# %%
import numpy as np
import pandas as pd
import scipy
from subprocess import check_output

# %%
import os, sys
from IPython.display import display
from IPython.display import Image as _Imgdis
from PIL import Image
import numpy as np
from time import time
from time import sleep

# %%
folder = "./TestImages"
data = []
onlyfiles = [f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]
for f in os.listdir(folder):
    file = "./TestImages/"+f
    print(file)
    img = Image.open(file)
    img.load()
    data.append(np.array(img, dtype = "int32"))

print(onlyfiles)
#print(data)
#for i in range(40, 42):
   # print(onlyfiles[i])
    #display(_Imgdis(filename=folder + "/" + onlyfiles[i], width=240, height=320))
# Out:
# ./TestImages/xnd3y.png
# ./TestImages/x6pdb.png
# ./TestImages/x44n4.png
# ./TestImages/xc68n.png
# ./TestImages/x347n.png
# ./TestImages/ydd3g.png
# ./TestImages/xymfn.png
# ./TestImages/xe6eb.png
# ./TestImages/ywn6f.png
# ./TestImages/ypw3d.png
# ./TestImages/yw7ny.png
# ./TestImages/y7mnm.png
# ./TestImages/yf347.png
# ./TestImages/xce8d.png
# ./TestImages/y2ye8.png
# ./TestImages/x277e.png
# ./TestImages/xf5g7.png
# ./TestImages/y7d75.png
# ./TestImages/ybfx6.png
# ./TestImages/xxney.png
# ./TestImages/xfg65.png
# ./TestImages/y32yy.png
# ./TestImages/yd755.png
# ./TestImages/yd38e.png
# ./TestImages/y5g87.png
# ./TestImages/x38fn.png
# ./TestImages/xyyyw.png
# ./TestImages/yw667.png
# ./TestImages/xxbm5.png
# ./TestImages/xnn4d.png
# ./TestImages/x5f54.png
# ./TestImages/x74b2.png
# ./TestImages/yew6p.png
# ./TestImages/y4g3b.png
# ./TestImages/x775w.png
# ./TestImages/yy824.png
# ./TestImages/yeyn4.png
# ./TestImages/yxd7m.png
# ./TestImages/x7422.png
# ./TestImages/xwx7d.png
# ...

# %%
#data = pd.Series(onlyfiles)
#indexes=[]

#for i in range(len(data)):
 #   indexes.append(i)
images1=pd.DataFrame({'images' : onlyfiles, 'pixel': data})
images1
# Out:
#        images                                              pixel
# 0   xnd3y.png  [[[192, 192, 192, 255], [192, 192, 192, 255], ...
# 1   x6pdb.png  [[[192, 192, 192, 255], [192, 192, 192, 255], ...
# 2   x44n4.png  [[[192, 192, 192, 255], [192, 192, 192, 255], ...
# 3   xc68n.png  [[[192, 192, 192, 255], [192, 192, 192, 255], ...
# 4   x347n.png  [[[192, 192, 192, 255], [192, 192, 192, 255], ...
# 5   ydd3g.png  [[[192, 192, 192, 255], [192, 192, 192, 255], ...
# 6   xymfn.png  [[[192, 192, 192, 255], [192, 192, 192, 255], ...
# 7   xe6eb.png  [[[192, 192, 192, 255], [192, 192, 192, 255], ...
# 8   ywn6f.png  [[[192, 192, 192, 255], [192, 192, 192, 255], ...
# 9   ypw3d.png  [[[192, 192, 192, 255], [192, 192, 192, 255], ...
# 10  yw7ny.png  [[[192, 192, 192, 255], [192, 192, 192, 255], ...
# 11  y7mnm.png  [[[192, 192, 192, 255], [192, 192, 192, 255], ...
# 12  yf347.png  [[[192, 192, 192, 255], [192, 192, 192, 255], ...
# ...

# %%
images1.to_csv('TestingData.csv')

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
a=mpimg.imread('./TestImages/x44n4.png')
a
# Out:
# array([[[0.7529412 , 0.7529412 , 0.7529412 , 1.        ],
#         [0.7529412 , 0.7529412 , 0.7529412 , 1.        ],
#         [0.7529412 , 0.7529412 , 0.7529412 , 1.        ],
#         ...,
#         [0.9843137 , 0.9843137 , 0.9843137 , 1.        ],
#         [0.9843137 , 0.9843137 , 0.9843137 , 1.        ],
#         [0.9843137 , 0.9843137 , 0.9843137 , 1.        ]],
#
#        [[0.7529412 , 0.7529412 , 0.7529412 , 1.        ],
#         [0.7529412 , 0.7529412 , 0.7529412 , 1.        ],
#         [0.7529412 , 0.7529412 , 0.7529412 , 1.        ],
#         ...,
#         [0.9843137 , 0.9843137 , 0.9843137 , 1.        ],
#         [0.9843137 , 0.9843137 , 0.9843137 , 1.        ],
#         [0.9843137 , 0.9843137 , 0.9843137 , 1.        ]],
#
#        [[0.7529412 , 0.7529412 , 0.7529412 , 1.        ],
#         [0.7529412 , 0.7529412 , 0.7529412 , 1.        ],
#         [0.7529412 , 0.7529412 , 0.7529412 , 1.        ],
#         ...,
# ...

# %%
plt.imshow(a)

# %%
e=a*255
e
# Out:
# array([[[192., 192., 192., 255.],
#         [192., 192., 192., 255.],
#         [192., 192., 192., 255.],
#         ...,
#         [251., 251., 251., 255.],
#         [251., 251., 251., 255.],
#         [251., 251., 251., 255.]],
#
#        [[192., 192., 192., 255.],
#         [192., 192., 192., 255.],
#         [192., 192., 192., 255.],
#         ...,
#         [251., 251., 251., 255.],
#         [251., 251., 251., 255.],
#         [251., 251., 251., 255.]],
#
#        [[192., 192., 192., 255.],
#         [192., 192., 192., 255.],
#         [192., 192., 192., 255.],
#         ...,
#         [251., 251., 251., 255.],
#         [251., 251., 251., 255.],
#         [251., 251., 251., 255.]],
#
#        ...,
#
#        [[195., 195., 195., 255.],
#         [195., 195., 195., 255.],
#         [195., 195., 195., 255.],
#         ...,
#         [254., 254., 254., 255.],
#         [254., 254., 254., 255.],
#         [254., 254., 254., 255.]],
#
#        [[195., 195., 195., 255.],
# ...

# %%
plt.imshow(e)

# %%
a
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x50 at 0x7F8DA108C5F8>

# %%
a=Image.open('./TestImages/x44n4.png')
a.load()
b=np.array(a,dtype='uint8')
b
# Out:
# array([[[192, 192, 192, 255],
#         [192, 192, 192, 255],
#         [192, 192, 192, 255],
#         ...,
#         [251, 251, 251, 255],
#         [251, 251, 251, 255],
#         [251, 251, 251, 255]],
#
#        [[192, 192, 192, 255],
#         [192, 192, 192, 255],
#         [192, 192, 192, 255],
#         ...,
#         [251, 251, 251, 255],
#         [251, 251, 251, 255],
#         [251, 251, 251, 255]],
#
#        [[192, 192, 192, 255],
#         [192, 192, 192, 255],
#         [192, 192, 192, 255],
#         ...,
#         [251, 251, 251, 255],
#         [251, 251, 251, 255],
#         [251, 251, 251, 255]],
#
#        ...,
#
#        [[195, 195, 195, 255],
#         [195, 195, 195, 255],
#         [195, 195, 195, 255],
#         ...,
#         [254, 254, 254, 255],
#         [254, 254, 254, 255],
#         [254, 254, 254, 255]],
#
#        [[195, 195, 195, 255],
#         [195, 195, 195, 255],
#         [195, 195, 195, 255],
#         ...,
#         [254, 254, 254, 255],
# ...

# %%
plt.imshow(b)
